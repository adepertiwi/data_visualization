# %%
# !pip install seaborn

import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# ...
# Setup Complete

# %%
# load data
heart_disease = pd.read_csv('input/heart.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# distribution of age using histogram
plt.figure(figsize=(10,6))
sns.distplot(a=heart_disease['age'], kde=False)
plt.title('Distribution of Age')
plt.show()
# Out:
# C:\Users\Wilb\AppData\Local\Temp\ipykernel_27220\4155053418.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=heart_disease['age'], kde=False)

# %%
# distribution of age using KDE
plt.figure(figsize=(10,6))
sns.kdeplot(data=heart_disease['age'], shade=True)
plt.title('Distribution of Age')
plt.show()
# Out:
# C:\Users\Wilb\AppData\Local\Temp\ipykernel_27220\353529546.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=heart_disease['age'], shade=True)

# %%
# 2D KDE plot
plt.figure(figsize=(10,6))
sns.jointplot(x=heart_disease['age'], y=heart_disease['chol'], kind="kde")
plt.title('Distribution of Age and Cholesterol')
plt.show()
